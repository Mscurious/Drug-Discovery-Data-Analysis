# %% [markdown]
# <a href="https://colab.research.google.com/github/Mscurious/Drug-Discovery-Data-Analysis/blob/main/Processing_Drug_Discovery_Data_Sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install chembl_webresource_client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jsonschema 4.19.1 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# referencing 0.30.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# ...

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('aromatase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references           organism  \
# 0  [{'xref_id': 'P11511', 'xref_name': None, 'xre...       Homo sapiens
# 1  [{'xref_id': 'P22443', 'xref_name': None, 'xre...  Rattus norvegicus
#
#               pref_name  score  species_group_flag target_chembl_id  \
# 0  Cytochrome P450 19A1   20.0               False       CHEMBL1978
# 1  Cytochrome P450 19A1   20.0               False       CHEMBL3859
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'P11511', 'component_descriptio...  SINGLE PROTEIN    9606
# 1  [{'accession': 'P22443', 'component_descriptio...  SINGLE PROTEIN   10116

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL3859'

# %% [markdown]
# Define a variable called activity

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")
df = pd.DataFrame.from_dict(res)

df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       530035                  []
# 1        None             None       539290                  []
# 2        None             None       553204                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL661155      Inhibition of rat ovarian Cytochrome P450 19A
# 1    CHEMBL649360  In vitro inhibition of rat ovarian aromatase c...
# 2    CHEMBL649360  In vitro inhibition of rat ovarian aromatase c...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#      target_organism      target_pref_name target_tax_id text_value  toid  \
# ...

# %% [markdown]
# Show the unique values in the standard type column

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# To create a csvfile with our code:

# %%
df.to_csv('bioactivity_data.csv', index=False)
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Copy the bioactivity data into the drive

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"
#-l helps us know what time we uploaded the data

! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# -rw------- 1 root root 5938 Oct 12 21:46 '/content/gdrive/My Drive/Colab Notebooks/data'

# %%
# !ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %% [markdown]
# Handling missing data

# %%
df2=df[df.standard_value.notna()]
df2
# Out:
#    action_type activity_comment  activity_id activity_properties  \
# 0         None             None       530035                  []
# 1         None             None       539290                  []
# 2         None             None       553204                  []
# 3         None             None       615833                  []
# 4         None             None       789248                  []
# 5         None             None       819891                  []
# 6         None             None     15742388                  []
# 7         None             None     15742389                  []
# 8         None             None     15742390                  []
# 9         None             None     16433981                  []
# 10        None             None     16433982                  []
#
#    assay_chembl_id                                  assay_description  \
# 0     CHEMBL661155      Inhibition of rat ovarian Cytochrome P450 19A
# ...

# %% [markdown]
# Data Pre-processing to help classify drugs as active or inactive.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# Iterate molecule_chemblid

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# Iterate canonical smiles to a list

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# TO combine all to a table

# %%
import pandas as pd

data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame(data_tuples, columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# Print or display the DataFrame to inspect the data
print(df3)
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL488                      CCC1(c2ccc(N)cc2)CCC(=O)NC1=O
# 1         CHEMBL93828                       O=C1c2cccc(O)c2CCC1Cc1ccncc1
# 2         CHEMBL90427                      COc1cccc2c1CCC(Cc1ccncc1)C2=O
# 3        CHEMBL100749             Cn1nnc2ccc(C(c3ccc(Cl)cc3)n3cncn3)cc21
# 4           CHEMBL488                      CCC1(c2ccc(N)cc2)CCC(=O)NC1=O
# 5        CHEMBL294361                    COc1ccc2c(c1)C1C(CC2)C1c1ccncc1
# 6         CHEMBL90585                     O=C1/C(=C/c2ccncc2)CCc2ccccc21
# 7        CHEMBL168434                   O=C1/C(=C/c2c[nH]cn2)CCc2ccccc21
# 8        CHEMBL169251                   O=C1/C(=C\c2c[nH]cn2)CCc2ccccc21
# 9       CHEMBL3753401  C[C@@H]1OC(=O)C[C@H]2[C@@H]3CCC4=CC(=O)CC[C@]4...
# 10      CHEMBL3754484  C[C@@H]1OC(=O)C[C@H]2[C@@H]3C=C[C@H]4C[C@@H](O...
#
#    bioactivity_class standard_value
# 0           inactive        34000.0
# ...

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

! ls -l
# Out:
# total 20
# -rw-r--r-- 1 root root 5938 Oct 12 21:43 bioactivity_data.csv
# -rw-r--r-- 1 root root  803 Oct 12 22:04 bioactivity_preprocessed_data.csv
# drwx------ 5 root root 4096 Oct 12 21:44 gdrive
# drwxr-xr-x 1 root root 4096 Oct 11 13:23 sample_data

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"
